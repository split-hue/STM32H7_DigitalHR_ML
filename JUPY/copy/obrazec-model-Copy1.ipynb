# %%
import tensorflow as tf
import numpy as np
import os
import struct
import matplotlib.pyplot as plt
from PIL import Image

# ============================================================
# 1. NASTAVITVE
# ============================================================
BITMAP_DIR = r'F:\FRI_DIPLOMSKA\-delovna mapa-\DATASET\sken-OBRAZEC\vse'
TEST_OSEBE = ['Dokument_2026-05-24_113242', '2026-05-24_113215']
FILTER_CRKE = None

# ============================================================
# 2. NALOŽI PODATKE
# ============================================================
X_all, y_all, osebe_all = [], [], []

for filename in os.listdir(BITMAP_DIR):
    if not filename.lower().endswith('.png'):
        continue

    # mal drgačno poimenovanje slik kle
    # Vzemi ime brez končnice .png
    ime_brez_png = filename.rsplit('.', 1)[0]
    parts = ime_brez_png.split('_')
    
    crka = parts[0] # Prva komponenta je vedno črka (npr. 'M')
    
    # Združimo vse vmesne dele, ki sestavljajo ime dokumenta/osebe
    celotno_ime = '_'.join(parts[1:])
    
    # OČISTIMO IME OSEBE: Odstranimo "_celicaXX" ali oklepaje na koncu, če obstajajo
    # To zagotovi, da "Dokument_... (8)" postane čisto "Dokument_..."
    if ' (' in celotno_ime:
        oseba = celotno_ime.split(' (')[0]
    elif '_celica' in celotno_ime:
        oseba = celotno_ime.split('_celica')[0]
    else:
        # Če je na koncu le zadnji del (npr. celica01) brez posebne oznake
        oseba = '_'.join(parts[1:-1]) if len(parts) > 2 else 'unknown'



    if FILTER_CRKE and crka not in FILTER_CRKE:
        continue

    img = Image.open(os.path.join(BITMAP_DIR, filename)).convert('L')
    # S tem spremeniš belo ozadje v črno in črno pisalo v belo
    pixels = 1.0 - (np.array(img, dtype=np.float32) / 255.0)
    #pixels = np.array(img, dtype=np.float32) / 255.0  # [0, 1]

    X_all.append(pixels.flatten())  # 28x28 -> 784
    y_all.append(crka)
    osebe_all.append(oseba)

X_all = np.array(X_all)
y_all = np.array(y_all)
osebe_all = np.array(osebe_all)

print(f"Skupaj vzorcev: {len(X_all)}")
print(f"Črke: {sorted(set(y_all))}")
print(f"Osebe: {sorted(set(osebe_all))}")

# ============================================================
# 3. TRAIN/TEST SPLIT PO OSEBAH
# ============================================================
train_mask = ~np.isin(osebe_all, TEST_OSEBE)
test_mask  =  np.isin(osebe_all, TEST_OSEBE)

X_train = X_all[train_mask]
y_train = y_all[train_mask]
X_test  = X_all[test_mask]
y_test  = y_all[test_mask]

print(f"\nTrain: {X_train.shape} — {np.unique(osebe_all[train_mask])}")
print(f"Test:  {X_test.shape} — {np.unique(osebe_all[test_mask])}")





labels_ordered = ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I',
                  'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š',
                  'T', 'U', 'V', 'Z', 'Ž']
label_to_idx = {l: i for i, l in enumerate(labels_ordered)}
y_train_enc = np.array([label_to_idx[l] for l in y_train])
y_test_enc  = np.array([label_to_idx[l] for l in y_test])


# ============================================================
# 4. VIZUALIZACIJA VZORCEV
# ============================================================
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i in range(min(10, len(X_all))):
    axes[i//5][i%5].imshow(X_all[i].reshape(28, 28), cmap='gray')
    axes[i//5][i%5].set_title(f'{y_all[i]} ({osebe_all[i]})')
    axes[i//5][i%5].axis('off')
plt.suptitle('Vzorci obrazca')
plt.tight_layout()
plt.show()

# ============================================================
# 5. MODEL
# ============================================================
n_classes = len(labels_ordered)

bitmap_model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(784,)),
    tf.keras.layers.Reshape((28, 28, 1)),

    tf.keras.layers.SeparableConv2D(16, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.SeparableConv2D(32, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),

    #tf.keras.layers.Flatten(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

bitmap_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                     loss='sparse_categorical_crossentropy',
                     metrics=['accuracy'])
bitmap_model.summary()

# ============================================================
# 6. TRENING
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True,
    verbose=1
)

history = bitmap_model.fit(
    X_train, y_train_enc,
    epochs=100,
    batch_size=16,
    validation_data=(X_test, y_test_enc),
    callbacks=[early_stop],
    verbose=1
)

# ============================================================
# 7. REZULTATI
# ============================================================
_, train_acc = bitmap_model.evaluate(X_train, y_train_enc, verbose=0)
_, test_acc  = bitmap_model.evaluate(X_test,  y_test_enc,  verbose=0)
print(f"\nTrain accuracy: {train_acc*100:.1f}%")
print(f"Test accuracy:  {test_acc*100:.1f}%")

# Graf
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Skupaj vzorcev: 2949
# Črke: [np.str_('A'), np.str_('B'), np.str_('C'), np.str_('D'), np.str_('E'), np.str_('F'), np.str_('G'), np.str_('H'), np.str_('I'), np.str_('J'), np.str_('K'), np.str_('L'), np.str_('M'), np.str_('N'), np.str_('O'), np.str_('P'), np.str_('R'), np.str_('S'), np.str_('T'), np.str_('U'), np.str_('V'), np.str_('Z'), np.str_('Č'), np.str_('Š'), np.str_('Ž')]
# Osebe: [np.str_('2026-05-24_113215'), np.str_('2026-05-24_113551'), np.str_('2026-05-24_113951'), np.str_('2026-05-24_114043'), np.str_('Dokument_2026-05-24_113103'), np.str_('Dokument_2026-05-24_113121'), np.str_('Dokument_2026-05-24_113129'), np.str_('Dokument_2026-05-24_113148'), np.str_('Dokument_2026-05-24_113156'), np.str_('Dokument_2026-05-24_113223'), np.str_('Dokument_2026-05-24_113242'), np.str_('Dokument_2026-05-24_113250'), np.str_('Dokument_2026-05-24_113309'), np.str_('Dokument_2026-05-24_113317'), np.str_('Dokument_2026-05-24_113336'), np.str_('Dokument_2026-05-24_113344'), np.str_('Dokument_2026-05-24_113404'), np.str_('Dokument_2026-05-24_113412'), np.str_('Dokument_2026-05-24_113431'), np.str_('Dokument_2026-05-24_113438'), np.str_('Dokument_2026-05-24_113457'), np.str_('Dokument_2026-05-24_113504'), np.str_('Dokument_2026-05-24_113524'), np.str_('Dokument_2026-05-24_113531'), np.str_('Dokument_2026-05-24_113559'), np.str_('Dokument_2026-05-24_113625'), np.str_('Dokument_2026-05-24_113643'), np.str_('Dokument_2026-05-24_113651'), np.str_('Dokument_2026-05-24_113717'), np.str_('Dokument_2026-05-24_113737'), np.str_('Dokument_2026-05-24_113745'), np.str_('Dokument_2026-05-24_113804'), np.str_('Dokument_2026-05-24_113812'), np.str_('Dokument_2026-05-24_113831'), np.str_('Dokument_2026-05-24_113839'), np.str_('Dokument_2026-05-24_113857'), np.str_('Dokument_2026-05-24_113905'), np.str_('Dokument_2026-05-24_113924'), np.str_('Dokument_2026-05-24_113932'), np.str_('Dokument_2026-05-24_113958'), np.str_('Dokument_2026-05-24_114017'), np.str_('Dokument_2026-05-24_114024'), np.str_('Dokument_2026-05-24_114050'), np.str_('Dokument_2026-05-24_114109'), np.str_('Dokument_2026-05-24_114117'), np.str_('Dokument_2026-05-24_114136'), np.str_('Dokument_2026-05-24_114202'), np.str_('Rokopis_2026-05-24_113709')]
#
# Train: (2805, 784) — ['2026-05-24_113551' '2026-05-24_113951' '2026-05-24_114043'
#  'Dokument_2026-05-24_113103' 'Dokument_2026-05-24_113121'
#  'Dokument_2026-05-24_113129' 'Dokument_2026-05-24_113148'
#  'Dokument_2026-05-24_113156' 'Dokument_2026-05-24_113223'
#  'Dokument_2026-05-24_113250' 'Dokument_2026-05-24_113309'
#  'Dokument_2026-05-24_113317' 'Dokument_2026-05-24_113336'
#  'Dokument_2026-05-24_113344' 'Dokument_2026-05-24_113404'
#  'Dokument_2026-05-24_113412' 'Dokument_2026-05-24_113431'
#  'Dokument_2026-05-24_113438' 'Dokument_2026-05-24_113457'
#  'Dokument_2026-05-24_113504' 'Dokument_2026-05-24_113524'
#  'Dokument_2026-05-24_113531' 'Dokument_2026-05-24_113559'
#  'Dokument_2026-05-24_113625' 'Dokument_2026-05-24_113643'
#  'Dokument_2026-05-24_113651' 'Dokument_2026-05-24_113717'
#  'Dokument_2026-05-24_113737' 'Dokument_2026-05-24_113745'
#  'Dokument_2026-05-24_113804' 'Dokument_2026-05-24_113812'
#  'Dokument_2026-05-24_113831' 'Dokument_2026-05-24_113839'
#  'Dokument_2026-05-24_113857' 'Dokument_2026-05-24_113905'
#  'Dokument_2026-05-24_113924' 'Dokument_2026-05-24_113932'
#  'Dokument_2026-05-24_113958' 'Dokument_2026-05-24_114017'
#  'Dokument_2026-05-24_114024' 'Dokument_2026-05-24_114050'
#  'Dokument_2026-05-24_114109' 'Dokument_2026-05-24_114117'
#  'Dokument_2026-05-24_114136' 'Dokument_2026-05-24_114202'
#  'Rokopis_2026-05-24_113709']
# Test:  (144, 784) — ['2026-05-24_113215' 'Dokument_2026-05-24_113242']
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)                    │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d (SeparableConv2D)   │ (None, 28, 28, 16)          │              41 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_1 (SeparableConv2D) │ (None, 14, 14, 32)          │             688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 32)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 25)                  │             825 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,938 (23.20 KB)
#  Trainable params: 5,842 (22.82 KB)
#  Non-trainable params: 96 (384.00 B)
# Epoch 1/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.0856 - loss: 3.1471 - val_accuracy: 0.0417 - val_loss: 3.2636
# Epoch 2/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1398 - loss: 2.8072 - val_accuracy: 0.0486 - val_loss: 3.1590
# Epoch 3/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1893 - loss: 2.5048 - val_accuracy: 0.2222 - val_loss: 2.6539
# Epoch 4/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2339 - loss: 2.3344 - val_accuracy: 0.1806 - val_loss: 2.4986
# Epoch 5/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2781 - loss: 2.1632 - val_accuracy: 0.3819 - val_loss: 1.9752
# Epoch 6/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3447 - loss: 2.0055 - val_accuracy: 0.0417 - val_loss: 7.2173
# Epoch 7/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3879 - loss: 1.8611 - val_accuracy: 0.1806 - val_loss: 3.7616
# Epoch 8/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4545 - loss: 1.6986 - val_accuracy: 0.2986 - val_loss: 2.2174
# Epoch 9/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4966 - loss: 1.5524 - val_accuracy: 0.0556 - val_loss: 11.4236
# Epoch 10/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5390 - loss: 1.4345 - val_accuracy: 0.1319 - val_loss: 8.1296
# Epoch 11/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5469 - loss: 1.3524 - val_accuracy: 0.1597 - val_loss: 2.9382
# Epoch 12/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5768 - loss: 1.2816 - val_accuracy: 0.4028 - val_loss: 1.7821
# Epoch 13/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6082 - loss: 1.2239 - val_accuracy: 0.4028 - val_loss: 1.6925
# Epoch 14/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6160 - loss: 1.1573 - val_accuracy: 0.2986 - val_loss: 3.0578
# Epoch 15/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6431 - loss: 1.1378 - val_accuracy: 0.1111 - val_loss: 11.5276
# Epoch 16/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6510 - loss: 1.0725 - val_accuracy: 0.4306 - val_loss: 1.8399
# Epoch 17/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6674 - loss: 1.0447 - val_accuracy: 0.2500 - val_loss: 2.9316
# Epoch 18/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6674 - loss: 1.0182 - val_accuracy: 0.3403 - val_loss: 3.1300
# Epoch 19/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6717 - loss: 0.9866 - val_accuracy: 0.5972 - val_loss: 1.0401
# Epoch 20/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6866 - loss: 0.9787 - val_accuracy: 0.1250 - val_loss: 10.5062
# Epoch 21/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7059 - loss: 0.9368 - val_accuracy: 0.5625 - val_loss: 1.4556
# Epoch 22/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6966 - loss: 0.9222 - val_accuracy: 0.2500 - val_loss: 3.8204
# Epoch 23/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7059 - loss: 0.8961 - val_accuracy: 0.4931 - val_loss: 1.4476
# Epoch 24/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7255 - loss: 0.8562 - val_accuracy: 0.5417 - val_loss: 1.3486
# Epoch 25/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7241 - loss: 0.8667 - val_accuracy: 0.7569 - val_loss: 0.7178
# Epoch 26/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7301 - loss: 0.8271 - val_accuracy: 0.2639 - val_loss: 3.8703
# Epoch 27/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7426 - loss: 0.7972 - val_accuracy: 0.4444 - val_loss: 1.8324
# Epoch 28/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7419 - loss: 0.8110 - val_accuracy: 0.8194 - val_loss: 0.5471
# Epoch 29/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7519 - loss: 0.7679 - val_accuracy: 0.7292 - val_loss: 0.7513
# Epoch 30/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7583 - loss: 0.7663 - val_accuracy: 0.7639 - val_loss: 0.6482
# Epoch 31/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7665 - loss: 0.7308 - val_accuracy: 0.5139 - val_loss: 1.4844
# Epoch 32/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7558 - loss: 0.7665 - val_accuracy: 0.4931 - val_loss: 1.7760
# Epoch 33/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7779 - loss: 0.7082 - val_accuracy: 0.3403 - val_loss: 5.0410
# Epoch 34/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7775 - loss: 0.7164 - val_accuracy: 0.3958 - val_loss: 2.0559
# Epoch 35/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7889 - loss: 0.6983 - val_accuracy: 0.6181 - val_loss: 1.2321
# Epoch 36/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7804 - loss: 0.7040 - val_accuracy: 0.7500 - val_loss: 0.7401
# Epoch 37/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7847 - loss: 0.6829 - val_accuracy: 0.3472 - val_loss: 3.8899
# Epoch 38/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7943 - loss: 0.6630 - val_accuracy: 0.5833 - val_loss: 1.3353
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
#
# Train accuracy: 77.3%
# Test accuracy:  81.9%

# %%
# ============================================================
# 8. PRETVORBA V TFLITE (z optimizacijo za mikrokontrolerje)
# ============================================================
converter = tf.lite.TFLiteConverter.from_keras_model(bitmap_model)

# Osnovna pretvorba
tflite_model = converter.convert()
with open(r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\obrazec.tflite', 'wb') as f:
    f.write(tflite_model)

# ŠE BOLJE: Kvantizacija (INT8 ali Float16) za hitrejši STM32
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
with open(r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\obrazec2.tflite', 'wb') as f:
    f.write(tflite_quant_model)

print("TFLite modela (navaden in kvantiziran) shranjena!")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmphm8gkfft\assets
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmphm8gkfft\assets
# Saved artifact at 'C:\Users\Ksenija\AppData\Local\Temp\tmphm8gkfft'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 784), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 25), dtype=tf.float32, name=None)
# Captures:
#   2617247465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247471888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247470352: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpr25vwe1t\assets
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpr25vwe1t\assets
# Saved artifact at 'C:\Users\Ksenija\AppData\Local\Temp\tmpr25vwe1t'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 784), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 25), dtype=tf.float32, name=None)
# Captures:
#   2617247465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247471888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2617247470352: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite modela (navaden in kvantiziran) shranjena!

# %% [markdown]
# **Pretvorba v .bin file da ga bomo dali na vezje**

# %%
# import numpy as np

# # Seznam črk točno v takem vrstnem redu, kot ga imaš v SLO_ABECEDA v C kodi
# labels_ordered = ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I',
#                   'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š',
#                   'T', 'U', 'V', 'Z', 'Ž']

# # Ustvarimo mapiranje: 'A' -> 0, 'B' -> 1, ...
# label_to_idx = {l: i for i, l in enumerate(labels_ordered)}

# def export_benchmark_data(X, y, filename=r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\zbirka_bitmaps.bin'):
#     with open(filename, "wb") as f:
#         for i in range(len(X)):
#             # 1. Pretvori črko v številko (npr. 'Č' -> 3)
#             char_label = str(y[i])
#             if char_label not in label_to_idx:
#                 print(f"Opozorilo: Črka {char_label} ni v seznamu! Preskakujem.")
#                 continue

#             numeric_label = label_to_idx[char_label]

#             # 2. Pripravi piksle (X_test so že floati med 0 in 1)
#             # Uporabimo float32, ker AI model v C-ju to pričakuje
#             pixels = X[i].astype(np.float32)

#             # 3. Zapakiraj (B=uint8, H=uint16, 784f=784 floatov)
#             # Skupaj: 1 + 2 + (784 * 4) = 3139 bajtov na vzorec
#             data = struct.pack('<BH784f', numeric_label, 784, *pixels)
#             f.write(data)

#     print(f"Končano! Ustvarjena datoteka '{filename}' s {len(X)} vzorci.")

# # Zaženi
# export_benchmark_data(X_test, y_test)

# %%
a_indices = np.where(y_all == 'A')[0]
a_idx = np.random.choice(a_indices)
plt.imshow(X_all[a_idx].reshape(28, 28), cmap='gray')
plt.title(f"Slika (obrazec): A")
plt.axis('off')
plt.show()

# %%
a_indices = np.where(y_all == 'A')[0]
a_idx = np.random.choice(a_indices)
plt.imshow(X_all[a_idx].reshape(28, 28), cmap='gray_r')
plt.title(f"Slika (obrazec): A")
plt.axis('off')
plt.show()

# %%
print(f"Skupaj vzorcev: {len(X_all)}")
# Out:
# Skupaj vzorcev: 2949
