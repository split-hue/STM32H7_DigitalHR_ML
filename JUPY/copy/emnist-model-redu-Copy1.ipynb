# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# 1. NASTAVITVE
# ============================================================
# Odstranjene: Q(16), W(22), X(23), Y(24) -> indeksi v EMNIST byclass so 10+
excluded_letters = {'Q', 'W', 'X', 'Y'}

labels_ordered = [l for l in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ' if l not in excluded_letters]
n_classes = len(labels_ordered)  # 22

# Originalni EMNIST indeksi za A-Z so 10-35
# Filtriramo ven Q=26, W=32, X=33, Y=34
excluded_emnist = {ord(l) - ord('A') + 10 for l in excluded_letters}  # {26, 32, 33, 34}

# Mapa: originalni label -> novi zaporedni indeks (0..21)
valid_labels = [i for i in range(10, 36) if i not in excluded_emnist]
label_remap = {orig: new for new, orig in enumerate(valid_labels)}

BITMAP_SAMPLE_COUNT = 2968
PER_CLASS = BITMAP_SAMPLE_COUNT // 22  # ~134 na črko
BATCH_SIZE = 16

# ============================================================
# 2. NALOŽI IN PRED-OBDELAJ PODATKE
# ============================================================
print("Nalaganje EMNIST byclass...")
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/byclass',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# Lookup tabela za remapiranje labelov
keys   = tf.constant(list(label_remap.keys()),   dtype=tf.int64)
values = tf.constant(list(label_remap.values()), dtype=tf.int64)
table  = tf.lookup.StaticHashTable(
    tf.lookup.KeyValueTensorInitializer(keys, values),
    default_value=-1
)
# Out:
# Nalaganje EMNIST byclass...

# %%
def filter_and_preprocess(image, label):
    label = tf.cast(label, tf.int64)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.transpose(image, perm=[1, 0, 2])  # EMNIST rotacija
    image = tf.reshape(image, (784,))
    new_label = table.lookup(label)
    return image, new_label

def is_valid(image, label):
    label = tf.cast(label, tf.int64)
    return tf.reduce_any(tf.equal(keys, label))

# da uzame enak št vzorcev na pos črko
ds_parts = []
for orig_label in valid_labels:  # valid_labels = [10,11,...,35 brez Q/W/X/Y]
    ds_part = (ds_train
        .filter(lambda img, lbl, ol=orig_label: tf.cast(lbl, tf.int64) == ol)
        .map(filter_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .take(PER_CLASS)
    )
    ds_parts.append(ds_part)

# združ vse razrede
from functools import reduce
ds_train = reduce(lambda a, b: a.concatenate(b), ds_parts)

ds_train = (ds_train
    .cache()
    .shuffle(10000)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE))

ds_test = (ds_test
    .filter(is_valid)
    .map(filter_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .cache()
    .prefetch(tf.data.AUTOTUNE))

# ============================================================
# 3. VIZUALIZACIJA
# ============================================================
sample_images, sample_labels = next(iter(ds_train))
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i in range(10):
    axes[i//5][i%5].imshow(sample_images[i].numpy().reshape(28, 28), cmap='gray')
    axes[i//5][i%5].set_title(labels_ordered[sample_labels[i].numpy()])
    axes[i//5][i%5].axis('off')
plt.suptitle('EMNIST vzorci (brez Q, W, X, Y)')
plt.tight_layout()
plt.show()

# ============================================================
# 4. MODEL
# ============================================================
emnist_model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(784,)),
    tf.keras.layers.Reshape((28, 28, 1)),
    
    tf.keras.layers.SeparableConv2D(16, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    
    tf.keras.layers.SeparableConv2D(32, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),

    #tf.keras.layers.Flatten(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax')  # 22 razredov
])

emnist_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
emnist_model.summary()

# ============================================================
# 5. TRENING
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True,
    verbose=1
)

history = emnist_model.fit(
    ds_train,
    epochs=100,
    validation_data=ds_test,
    callbacks=[early_stop],
    verbose=1
)

# ============================================================
# 6. REZULTATI
# ============================================================
_, train_acc = emnist_model.evaluate(ds_train, verbose=0)
_, test_acc  = emnist_model.evaluate(ds_test,  verbose=0)
print(f"\nTrain accuracy: {train_acc*100:.1f}%")
print(f"Test accuracy:  {test_acc*100:.1f}%")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)                    │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d (SeparableConv2D)   │ (None, 28, 28, 16)          │              41 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_1 (SeparableConv2D) │ (None, 14, 14, 32)          │             688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 32)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 22)                  │             726 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,839 (22.81 KB)
#  Trainable params: 5,743 (22.43 KB)
#  Non-trainable params: 96 (384.00 B)
# Epoch 1/100
#     182/Unknown 8s 7ms/step - accuracy: 0.0759 - loss: 3.0668
# C:\Users\Ksenija\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - accuracy: 0.0943 - loss: 2.9922 - val_accuracy: 0.0709 - val_loss: 3.0282
# Epoch 2/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.1689 - loss: 2.6548 - val_accuracy: 0.1567 - val_loss: 2.9363
# Epoch 3/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.2469 - loss: 2.3507 - val_accuracy: 0.2121 - val_loss: 2.7445
# Epoch 4/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.2734 - loss: 2.1944 - val_accuracy: 0.1039 - val_loss: 3.0568
# Epoch 5/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.3301 - loss: 2.0877 - val_accuracy: 0.2757 - val_loss: 2.3848
# Epoch 6/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.3477 - loss: 1.9617 - val_accuracy: 0.2535 - val_loss: 2.4182
# Epoch 7/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.3796 - loss: 1.8777 - val_accuracy: 0.2936 - val_loss: 2.2688
# Epoch 8/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.3959 - loss: 1.8100 - val_accuracy: 0.4095 - val_loss: 1.9110
# Epoch 9/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.4349 - loss: 1.7118 - val_accuracy: 0.5133 - val_loss: 1.5567
# Epoch 10/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.4505 - loss: 1.6280 - val_accuracy: 0.4815 - val_loss: 1.5837
# Epoch 11/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.4766 - loss: 1.5698 - val_accuracy: 0.5005 - val_loss: 1.4907
# Epoch 12/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5081 - loss: 1.4908 - val_accuracy: 0.5318 - val_loss: 1.5190
# Epoch 13/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5315 - loss: 1.4151 - val_accuracy: 0.6586 - val_loss: 1.1228
# Epoch 14/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5488 - loss: 1.3552 - val_accuracy: 0.5548 - val_loss: 1.4107
# Epoch 15/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.5675 - loss: 1.3204 - val_accuracy: 0.6701 - val_loss: 1.1174
# Epoch 16/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.5950 - loss: 1.2321 - val_accuracy: 0.6832 - val_loss: 1.0312
# Epoch 17/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.6065 - loss: 1.1742 - val_accuracy: 0.6252 - val_loss: 1.1704
# Epoch 18/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.6286 - loss: 1.1347 - val_accuracy: 0.6476 - val_loss: 1.0996
# Epoch 19/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - accuracy: 0.6367 - loss: 1.0808 - val_accuracy: 0.6373 - val_loss: 1.1553
# Epoch 20/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.6635 - loss: 1.0420 - val_accuracy: 0.7582 - val_loss: 0.7927
# Epoch 21/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.6686 - loss: 1.0020 - val_accuracy: 0.6395 - val_loss: 1.1273
# Epoch 22/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.6883 - loss: 0.9899 - val_accuracy: 0.7430 - val_loss: 0.8670
# Epoch 23/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.6889 - loss: 0.9635 - val_accuracy: 0.7199 - val_loss: 0.8637
# Epoch 24/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - accuracy: 0.6978 - loss: 0.9435 - val_accuracy: 0.7127 - val_loss: 0.9013
# Epoch 25/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - accuracy: 0.6981 - loss: 0.9217 - val_accuracy: 0.5977 - val_loss: 1.2548
# Epoch 26/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - accuracy: 0.7049 - loss: 0.9030 - val_accuracy: 0.7050 - val_loss: 0.9536
# Epoch 27/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.7093 - loss: 0.9029 - val_accuracy: 0.6367 - val_loss: 1.0702
# Epoch 28/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.7140 - loss: 0.8469 - val_accuracy: 0.6803 - val_loss: 1.0205
# Epoch 29/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.7157 - loss: 0.8602 - val_accuracy: 0.6380 - val_loss: 1.1851
# Epoch 30/100
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.7310 - loss: 0.8333 - val_accuracy: 0.6795 - val_loss: 0.9923
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
#
# Train accuracy: 74.3%
# Test accuracy:  75.8%

# %%
# ============================================================
# 7. PRETVORBA V TFLITE (Kvantizacija na 8-bit)
# ============================================================
converter = tf.lite.TFLiteConverter.from_keras_model(emnist_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open(r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\emnist-redu.tflite', 'wb') as f:
    f.write(tflite_model)

print(f"TFLite model shranjen: {len(tflite_model) / 1024:.1f} KB")

# Vizualizacija vzorca
for img, label in ds_train.take(1):
    plt.imshow(img[0].numpy().reshape(28, 28), cmap='gray')
    plt.title(f"Label: {labels_ordered[label[0].numpy()]}")
    plt.show()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpxu7a6brr\assets
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpxu7a6brr\assets
# Saved artifact at 'C:\Users\Ksenija\AppData\Local\Temp\tmpxu7a6brr'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 784), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 22), dtype=tf.float32, name=None)
# Captures:
#   2098613392528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613393488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613394448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613395408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613395600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613393680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613394640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613395984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613395024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613394832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613397136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613397328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613394064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613393296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613395792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613396752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613396560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613396944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613399440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2098613397904: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model shranjen: 19.1 KB

# %%
import struct
# ============================================================
# 8. IZVOZ TESTNIH VZORCEV
# ============================================================
def export_emnist_benchmark(ds, filename=r"F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\zbirka_emnist.bin", max_samples=225):
    count = 0
    with open(filename, "wb") as f:
        for batch_images, batch_labels in ds:
            images = batch_images.numpy()
            labels = batch_labels.numpy()
            for i in range(len(images)):
                if count >= max_samples:
                    break
                pixels = images[i].flatten().astype(np.float32)
                assert len(pixels) == 784
                label = int(labels[i])
                data = struct.pack('<BH784f', label, 784, *pixels)
                f.write(data)
                count += 1
            if count >= max_samples:
                break
    print(f"Končano! {count} vzorcev shranjenih v '{filename}'")

export_emnist_benchmark(ds_test)
# Out:
# Končano! 225 vzorcev shranjenih v 'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\zbirka_emnist.bin'

# %%
for img, label in ds_train.unbatch().filter(lambda img, lbl: lbl == 0).batch(1).take(1):
    plt.imshow(img[0].numpy().reshape(28, 28), cmap='gray_r')  # <-- gray_r invertira
    plt.title(f"EMNIST: A")
    plt.axis('off')
    plt.show()
