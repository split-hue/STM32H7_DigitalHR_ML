# %%
import tensorflow as tf
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import struct

# ============================================================
# 1. NASTAVITVE
# ============================================================
STROKE_DIR = r'F:\FRI_DIPLOMSKA\-delovna mapa-\DATASET\dataset\strokes'
MAX_STROKES = 5
POINTS_PER_STROKE = 32
TEST_OSEBE = ['1009', 'pika', 'K']  # osebe za testiranje
FILTER_CRKE = None  # None = vse črke, ali npr. ['A','B'] za samo A in B

# ============================================================
# 2. FUNKCIJE
# ============================================================
def resample_stroke(points, max_strokes=MAX_STROKES, points_per_stroke=POINTS_PER_STROKE):
    strokes = []
    current = []
    for p in points:
        if p['x'] == -1:
            if current:
                strokes.append(current)
                current = []
        else:
            current.append((p['x'], p['y']))
    if current:
        strokes.append(current)
    if not strokes:
        return None

    all_pts = np.array([p for s in strokes for p in s])
    x_min, x_max = all_pts[:,0].min(), all_pts[:,0].max()
    y_min, y_max = all_pts[:,1].min(), all_pts[:,1].max()

    result = np.zeros((max_strokes, points_per_stroke, 2))
    for i, stroke in enumerate(strokes[:max_strokes]):
        if len(stroke) < 2:
            continue
        coords = np.array(stroke)
        distances = np.sqrt(np.sum(np.diff(coords, axis=0)**2, axis=1))
        cumdist = np.concatenate([[0], np.cumsum(distances)])
        total_dist = cumdist[-1]
        if total_dist == 0:
            continue
        sample_points = np.linspace(0, total_dist, points_per_stroke)
        xs = np.interp(sample_points, cumdist, coords[:,0])
        ys = np.interp(sample_points, cumdist, coords[:,1])
        xs = (xs - x_min) / (x_max - x_min + 1e-8)
        ys = (ys - y_min) / (y_max - y_min + 1e-8)
        result[i] = np.column_stack([xs, ys])

    return result.flatten()  # 320 vrednosti

# ============================================================
# 3. NALOŽI PODATKE
# ============================================================
X_all, y_all, osebe_all = [], [], []

for filename in os.listdir(STROKE_DIR):
    if not filename.endswith('.json'):
        continue
    crka = filename[0]
    if FILTER_CRKE and crka not in FILTER_CRKE:
        continue

    parts = filename.split('_')
    oseba = parts[1] if len(parts) > 1 else 'unknown'

    with open(os.path.join(STROKE_DIR, filename), 'r') as f:
        points = json.load(f)

    resampled = resample_stroke(points)
    if resampled is None:
        continue

    X_all.append(resampled)
    y_all.append(crka)
    osebe_all.append(oseba)

X_all = np.array(X_all)
y_all = np.array(y_all)
osebe_all = np.array(osebe_all)

print(f"Skupaj vzorcev: {len(X_all)}")
print(f"Črke: {sorted(set(y_all))}")
print(f"Osebe: {sorted(set(osebe_all))}")

# ============================================================
# 4. TRAIN/TEST SPLIT PO OSEBAH
# ============================================================
train_mask = ~np.isin(osebe_all, TEST_OSEBE)
test_mask = np.isin(osebe_all, TEST_OSEBE)

X_train = X_all[train_mask]
y_train = y_all[train_mask]
X_test = X_all[test_mask]
y_test = y_all[test_mask]

print(f"\nTrain: {X_train.shape} — {np.unique(osebe_all[train_mask])}")
print(f"Test:  {X_test.shape} — {np.unique(osebe_all[test_mask])}")


labels_ordered = ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I',
                  'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š',
                  'T', 'U', 'V', 'Z', 'Ž']
label_to_idx = {l: i for i, l in enumerate(labels_ordered)}
n_classes = len(labels_ordered)

y_train_enc = np.array([label_to_idx[c] for c in y_train])
y_test_enc  = np.array([label_to_idx[c] for c in y_test])
print(f"Razredi: {labels_ordered}")
# ============================================================
# 5. VIZUALIZACIJA VZORCEV
# ============================================================
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i in range(min(10, len(X_all))):
    data = X_all[i].reshape(5, 32, 2)
    for stroke in data:
        if stroke.sum() == 0:
            continue
        axes[i//5][i%5].plot(stroke[:,0], 1-stroke[:,1], linewidth=2)
    axes[i//5][i%5].set_title(f'{y_all[i]} ({osebe_all[i]})')
    axes[i//5][i%5].set_xlim(0, 1)
    axes[i//5][i%5].set_ylim(0, 1)
    axes[i//5][i%5].axis('off')
plt.suptitle('Stroke vzorci iz dataseta')
plt.tight_layout()
plt.show()

# ============================================================
# 6. MODEL - pravilna arhitektura za stroke podatke
# ============================================================
n_classes = len(labels_ordered)

inputs = tf.keras.layers.Input(shape=(320,))

# Reshape v (5 strokeov, 64 vrednosti) — vsak stroke je svoja "vrstica"
x = tf.keras.layers.Reshape((5, 64))(inputs)  # 5 × (32točk × 2koordinati)

# Conv1D zdaj gleda vzdolž strokeov, ne čez koordinate
x = tf.keras.layers.Conv1D(32, 3, activation='relu', padding='same')(x)
x = tf.keras.layers.Conv1D(64, 3, activation='relu', padding='same')(x)
x = tf.keras.layers.GlobalAveragePooling1D()(x)

x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(32, activation='relu')(x)
x = tf.keras.layers.Dense(n_classes, activation='softmax')(x)

stroke_model = tf.keras.Model(inputs, x)

stroke_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# 7. TRENING
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True,
    verbose=1
)

history = stroke_model.fit(
    X_train, y_train_enc,
    epochs=100,
    batch_size=16,
    validation_data=(X_test, y_test_enc),
    callbacks=[early_stop],
    verbose=1
)

# ============================================================
# 8. REZULTATI
# ============================================================
_, train_acc = stroke_model.evaluate(X_train, y_train_enc, verbose=0)
_, test_acc = stroke_model.evaluate(X_test, y_test_enc, verbose=0)
print(f"\nTrain accuracy: {train_acc*100:.1f}%")
print(f"Test accuracy:  {test_acc*100:.1f}%")

# Graf
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Skupaj vzorcev: 2968
# Črke: [np.str_('A'), np.str_('B'), np.str_('C'), np.str_('D'), np.str_('E'), np.str_('F'), np.str_('G'), np.str_('H'), np.str_('I'), np.str_('J'), np.str_('K'), np.str_('L'), np.str_('M'), np.str_('N'), np.str_('O'), np.str_('P'), np.str_('R'), np.str_('S'), np.str_('T'), np.str_('U'), np.str_('V'), np.str_('Z'), np.str_('Č'), np.str_('Š'), np.str_('Ž')]
# Osebe: [np.str_(',,'), np.str_('1009'), np.str_('232323'), np.str_('69'), np.str_('Ana'), np.str_('Bruih'), np.str_('CritKill'), np.str_('Diablo'), np.str_('Gabor'), np.str_('Gilda Fejniković'), np.str_('Hamorii'), np.str_('Hana'), np.str_('Hnabči'), np.str_('Janez'), np.str_('Janez Januš'), np.str_('Jerry'), np.str_('K'), np.str_('Klara'), np.str_('Ks'), np.str_('Ksenija'), np.str_('Lolek'), np.str_('Lt'), np.str_('Martin'), np.str_('NejcYami'), np.str_('Ok'), np.str_('Petra'), np.str_('Ponižni prevozniki'), np.str_('Pos1'), np.str_('Pos2'), np.str_('Poss'), np.str_('Steve'), np.str_('Tamara'), np.str_('Trupina'), np.str_('Turgcat'), np.str_('Vikipiki3'), np.str_('cilke'), np.str_('junci4'), np.str_('mr'), np.str_('nat'), np.str_('nina'), np.str_('pika'), np.str_('say gex'), np.str_('skadi'), np.str_('ub'), np.str_('Žiga'), np.str_('🐢')]
#
# Train: (2743, 320) — [',,' '232323' '69' 'Ana' 'Bruih' 'CritKill' 'Diablo' 'Gabor'
#  'Gilda Fejniković' 'Hamorii' 'Hana' 'Hnabči' 'Janez' 'Janez Januš'
#  'Jerry' 'Klara' 'Ks' 'Ksenija' 'Lolek' 'Lt' 'Martin' 'NejcYami' 'Ok'
#  'Petra' 'Ponižni prevozniki' 'Pos1' 'Pos2' 'Poss' 'Steve' 'Tamara'
#  'Trupina' 'Turgcat' 'Vikipiki3' 'cilke' 'junci4' 'mr' 'nat' 'nina'
#  'say gex' 'skadi' 'ub' 'Žiga' '🐢']
# Test:  (225, 320) — ['1009' 'K' 'pika']
# Razredi: ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š', 'T', 'U', 'V', 'Z', 'Ž']
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1608 - loss: 2.8766 - val_accuracy: 0.4089 - val_loss: 2.0140
# Epoch 2/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4943 - loss: 1.6398 - val_accuracy: 0.7156 - val_loss: 1.0808
# Epoch 3/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6599 - loss: 1.0970 - val_accuracy: 0.8356 - val_loss: 0.6994
# Epoch 4/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7310 - loss: 0.8712 - val_accuracy: 0.7956 - val_loss: 0.6639
# Epoch 5/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7816 - loss: 0.7494 - val_accuracy: 0.8444 - val_loss: 0.4965
# Epoch 6/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8071 - loss: 0.6470 - val_accuracy: 0.8978 - val_loss: 0.4296
# Epoch 7/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8272 - loss: 0.5909 - val_accuracy: 0.9067 - val_loss: 0.3759
# Epoch 8/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8560 - loss: 0.5013 - val_accuracy: 0.8933 - val_loss: 0.3357
# Epoch 9/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8545 - loss: 0.4783 - val_accuracy: 0.9022 - val_loss: 0.3378
# Epoch 10/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8684 - loss: 0.4439 - val_accuracy: 0.8711 - val_loss: 0.3618
# Epoch 11/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8742 - loss: 0.4282 - val_accuracy: 0.9200 - val_loss: 0.3119
# Epoch 12/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8808 - loss: 0.3958 - val_accuracy: 0.8578 - val_loss: 0.3320
# Epoch 13/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8972 - loss: 0.3498 - val_accuracy: 0.8933 - val_loss: 0.2986
# Epoch 14/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8987 - loss: 0.3430 - val_accuracy: 0.9067 - val_loss: 0.2472
# Epoch 15/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9096 - loss: 0.3132 - val_accuracy: 0.9111 - val_loss: 0.2459
# Epoch 16/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9078 - loss: 0.2951 - val_accuracy: 0.9333 - val_loss: 0.2136
# Epoch 17/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9121 - loss: 0.2968 - val_accuracy: 0.9244 - val_loss: 0.2178
# Epoch 18/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9074 - loss: 0.2847 - val_accuracy: 0.9378 - val_loss: 0.2041
# Epoch 19/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9191 - loss: 0.2655 - val_accuracy: 0.9467 - val_loss: 0.1840
# Epoch 20/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9242 - loss: 0.2561 - val_accuracy: 0.9511 - val_loss: 0.1534
# Epoch 21/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9249 - loss: 0.2493 - val_accuracy: 0.9467 - val_loss: 0.1447
# Epoch 22/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9296 - loss: 0.2379 - val_accuracy: 0.9556 - val_loss: 0.1548
# Epoch 23/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9333 - loss: 0.2306 - val_accuracy: 0.9600 - val_loss: 0.1832
# Epoch 24/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9275 - loss: 0.2338 - val_accuracy: 0.9600 - val_loss: 0.1409
# Epoch 25/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9315 - loss: 0.2118 - val_accuracy: 0.9422 - val_loss: 0.1738
# Epoch 26/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9380 - loss: 0.2111 - val_accuracy: 0.9422 - val_loss: 0.1574
# Epoch 27/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9391 - loss: 0.1952 - val_accuracy: 0.9511 - val_loss: 0.1856
# Epoch 28/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9471 - loss: 0.1756 - val_accuracy: 0.9600 - val_loss: 0.1264
# Epoch 29/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9435 - loss: 0.1919 - val_accuracy: 0.9511 - val_loss: 0.1651
# Epoch 30/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9402 - loss: 0.1864 - val_accuracy: 0.9511 - val_loss: 0.1268
# Epoch 31/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9439 - loss: 0.1791 - val_accuracy: 0.9511 - val_loss: 0.1400
# Epoch 32/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9486 - loss: 0.1666 - val_accuracy: 0.9467 - val_loss: 0.1429
# Epoch 33/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9446 - loss: 0.1753 - val_accuracy: 0.9556 - val_loss: 0.1495
# Epoch 34/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9424 - loss: 0.1799 - val_accuracy: 0.9556 - val_loss: 0.1538
# Epoch 35/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9519 - loss: 0.1638 - val_accuracy: 0.9467 - val_loss: 0.1102
# Epoch 36/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9479 - loss: 0.1581 - val_accuracy: 0.9644 - val_loss: 0.1099
# Epoch 37/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9592 - loss: 0.1359 - val_accuracy: 0.9556 - val_loss: 0.1160
# Epoch 38/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9544 - loss: 0.1407 - val_accuracy: 0.9644 - val_loss: 0.0948
# Epoch 39/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9533 - loss: 0.1449 - val_accuracy: 0.9644 - val_loss: 0.1399
# Epoch 40/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9606 - loss: 0.1285 - val_accuracy: 0.9644 - val_loss: 0.1045
# Epoch 41/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9530 - loss: 0.1412 - val_accuracy: 0.9600 - val_loss: 0.1059
# Epoch 42/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9570 - loss: 0.1354 - val_accuracy: 0.9556 - val_loss: 0.1176
# Epoch 43/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9624 - loss: 0.1183 - val_accuracy: 0.9467 - val_loss: 0.1398
# Epoch 44/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9566 - loss: 0.1289 - val_accuracy: 0.9644 - val_loss: 0.1111
# Epoch 45/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9606 - loss: 0.1263 - val_accuracy: 0.9644 - val_loss: 0.0857
# Epoch 46/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9654 - loss: 0.1054 - val_accuracy: 0.9511 - val_loss: 0.1064
# Epoch 47/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9643 - loss: 0.1062 - val_accuracy: 0.9600 - val_loss: 0.1095
# Epoch 48/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9614 - loss: 0.1142 - val_accuracy: 0.9600 - val_loss: 0.1034
# Epoch 49/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9617 - loss: 0.1221 - val_accuracy: 0.9556 - val_loss: 0.1117
# Epoch 50/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9672 - loss: 0.1076 - val_accuracy: 0.9467 - val_loss: 0.1157
# Epoch 51/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9632 - loss: 0.1063 - val_accuracy: 0.9600 - val_loss: 0.1060
# Epoch 52/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9668 - loss: 0.1030 - val_accuracy: 0.9511 - val_loss: 0.1189
# Epoch 53/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9665 - loss: 0.1101 - val_accuracy: 0.9644 - val_loss: 0.0827
# Epoch 54/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9694 - loss: 0.0906 - val_accuracy: 0.9689 - val_loss: 0.0966
# Epoch 55/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9697 - loss: 0.0976 - val_accuracy: 0.9644 - val_loss: 0.1152
# Epoch 56/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9719 - loss: 0.0864 - val_accuracy: 0.9422 - val_loss: 0.1376
# Epoch 57/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9621 - loss: 0.1100 - val_accuracy: 0.9822 - val_loss: 0.0648
# Epoch 58/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9665 - loss: 0.0972 - val_accuracy: 0.9644 - val_loss: 0.0700
# Epoch 59/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9752 - loss: 0.0778 - val_accuracy: 0.9644 - val_loss: 0.0780
# Epoch 60/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9708 - loss: 0.0869 - val_accuracy: 0.9689 - val_loss: 0.0766
# Epoch 61/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9657 - loss: 0.0988 - val_accuracy: 0.9733 - val_loss: 0.0889
# Epoch 62/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9679 - loss: 0.0789 - val_accuracy: 0.9733 - val_loss: 0.0699
# Epoch 63/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9756 - loss: 0.0695 - val_accuracy: 0.9778 - val_loss: 0.0779
# Epoch 64/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9741 - loss: 0.0874 - val_accuracy: 0.9644 - val_loss: 0.0803
# Epoch 65/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9738 - loss: 0.0821 - val_accuracy: 0.9200 - val_loss: 0.3562
# Epoch 66/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9624 - loss: 0.1028 - val_accuracy: 0.9733 - val_loss: 0.0635
# Epoch 67/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9748 - loss: 0.0700 - val_accuracy: 0.9733 - val_loss: 0.0700
# Epoch 68/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0847 - val_accuracy: 0.9822 - val_loss: 0.0687
# Epoch 69/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9716 - loss: 0.0804 - val_accuracy: 0.9333 - val_loss: 0.2025
# Epoch 70/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9752 - loss: 0.0707 - val_accuracy: 0.9600 - val_loss: 0.1135
# Epoch 71/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9767 - loss: 0.0733 - val_accuracy: 0.9689 - val_loss: 0.0755
# Epoch 72/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9770 - loss: 0.0704 - val_accuracy: 0.9556 - val_loss: 0.0922
# Epoch 73/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9716 - loss: 0.0819 - val_accuracy: 0.9600 - val_loss: 0.1067
# Epoch 74/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9759 - loss: 0.0755 - val_accuracy: 0.9733 - val_loss: 0.0615
# Epoch 75/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9763 - loss: 0.0688 - val_accuracy: 0.9733 - val_loss: 0.0777
# Epoch 76/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0823 - val_accuracy: 0.9733 - val_loss: 0.0809
# Epoch 77/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9759 - loss: 0.0753 - val_accuracy: 0.9600 - val_loss: 0.0781
# Epoch 78/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9774 - loss: 0.0582 - val_accuracy: 0.9467 - val_loss: 0.1299
# Epoch 79/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9807 - loss: 0.0633 - val_accuracy: 0.9689 - val_loss: 0.0813
# Epoch 80/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9763 - loss: 0.0718 - val_accuracy: 0.9467 - val_loss: 0.1516
# Epoch 81/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9774 - loss: 0.0725 - val_accuracy: 0.9778 - val_loss: 0.0595
# Epoch 82/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9829 - loss: 0.0498 - val_accuracy: 0.9733 - val_loss: 0.0687
# Epoch 83/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9810 - loss: 0.0631 - val_accuracy: 0.9689 - val_loss: 0.1113
# Epoch 84/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9829 - loss: 0.0546 - val_accuracy: 0.9733 - val_loss: 0.0791
# Epoch 85/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9741 - loss: 0.0715 - val_accuracy: 0.9689 - val_loss: 0.0694
# Epoch 86/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9781 - loss: 0.0612 - val_accuracy: 0.9867 - val_loss: 0.0678
# Epoch 87/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9829 - loss: 0.0480 - val_accuracy: 0.9822 - val_loss: 0.0674
# Epoch 88/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9814 - loss: 0.0507 - val_accuracy: 0.9733 - val_loss: 0.0766
# Epoch 89/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9825 - loss: 0.0536 - val_accuracy: 0.9644 - val_loss: 0.0866
# Epoch 90/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9778 - loss: 0.0673 - val_accuracy: 0.9867 - val_loss: 0.0527
# Epoch 91/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9807 - loss: 0.0554 - val_accuracy: 0.9600 - val_loss: 0.0773
# Epoch 92/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0798 - val_accuracy: 0.9778 - val_loss: 0.0600
# Epoch 93/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9756 - loss: 0.0663 - val_accuracy: 0.9822 - val_loss: 0.0579
# Epoch 94/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9861 - loss: 0.0446 - val_accuracy: 0.9689 - val_loss: 0.0720
# Epoch 95/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9799 - loss: 0.0522 - val_accuracy: 0.9733 - val_loss: 0.0706
# Epoch 96/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9763 - loss: 0.0697 - val_accuracy: 0.9733 - val_loss: 0.0796
# Epoch 97/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9796 - loss: 0.0631 - val_accuracy: 0.9644 - val_loss: 0.1215
# Epoch 98/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9825 - loss: 0.0471 - val_accuracy: 0.9644 - val_loss: 0.0872
# Epoch 99/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9785 - loss: 0.0646 - val_accuracy: 0.9689 - val_loss: 0.0906
# Epoch 100/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9858 - loss: 0.0449 - val_accuracy: 0.9689 - val_loss: 0.0718
# Epoch 100: early stopping
# Restoring model weights from the end of the best epoch: 90.
#
# Train accuracy: 99.2%
# Test accuracy:  98.7%

# %%
# ============================================================
# 10. PRETVORBA V TFLITE (z optimizacijo za mikrokontrolerje)
# ============================================================
converter = tf.lite.TFLiteConverter.from_keras_model(stroke_model)

# Osnovna pretvorba
tflite_model = converter.convert()
with open(r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\strokes\strokes.tflite', 'wb') as f:
    f.write(tflite_model)

# ŠE BOLJE: Kvantizacija (INT8 ali Float16) za hitrejši STM32
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
with open(r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\strokes\strokes2.tflite', 'wb') as f:
    f.write(tflite_quant_model)

print("TFLite modela (navaden in kvantiziran) shranjena!")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpb9pj3m8j\assets
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpb9pj3m8j\assets
# Saved artifact at 'C:\Users\Ksenija\AppData\Local\Temp\tmpb9pj3m8j'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 320), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 25), dtype=tf.float32, name=None)
# Captures:
#   1599902534928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902535888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902535696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902538192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537232: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpdu4z16_x\assets
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpdu4z16_x\assets
# Saved artifact at 'C:\Users\Ksenija\AppData\Local\Temp\tmpdu4z16_x'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 320), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 25), dtype=tf.float32, name=None)
# Captures:
#   1599902534928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902535888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902535696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902538192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1599902537232: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite modela (navaden in kvantiziran) shranjena!

# %% [markdown]
# **Pretvorba v .bin file da ga bomo dali na vezje**

# %%
# import numpy as np

# # Seznam črk točno v takem vrstnem redu, kot ga imaš v SLO_ABECEDA v C kodi
# labels_ordered = ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I',
#                   'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š',
#                   'T', 'U', 'V', 'Z', 'Ž']

# # Ustvarimo mapiranje: 'A' -> 0, 'B' -> 1, ...
# label_to_idx = {l: i for i, l in enumerate(labels_ordered)}

# def export_benchmark_data(X, y, filename=r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\strokes\zbirka_strokes.bin'):
#     with open(filename, "wb") as f:
#         for i in range(len(X)):
#             # 1. Pretvori črko v številko (npr. 'Č' -> 3)
#             char_label = str(y[i])
#             if char_label not in label_to_idx:
#                 print(f"Opozorilo: Črka {char_label} ni v seznamu! Preskakujem.")
#                 continue
            
#             numeric_label = label_to_idx[char_label]
            
#             # 2. Pripravi točke (X_test so že floati med 0 in 1 ali podobno)
#             # Uporabimo float32, ker AI model v C-ju to pričakuje
#             points = X[i].astype(np.float32) 
            
#             # 3. Zapakiraj (B=uint8, H=uint16, 320f=320 floatov)
#             # Skupaj: 1 + 2 + (320 * 4) = 1283 bajtov na vzorec
#             data = struct.pack(f'<BH320f', numeric_label, 160, *points)
#             f.write(data)
            
#     print(f"Končano! Ustvarjena datoteka '{filename}' s {len(X)} vzorci.")

# # Zaženi
# export_benchmark_data(X_test, y_test)

# %%
a_indices = np.where(y_all == 'A')[0]
a_idx = np.random.choice(a_indices)

data = X_all[a_idx].reshape(5, 32, 2)
for stroke in data:
    if stroke.sum() == 0:
        continue
    plt.plot(stroke[:,0], 1-stroke[:,1], linewidth=2)
plt.title(f"Poteze (app): A")
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.axis('off')
plt.show()

# %%
print(f"Skupaj vzorcev: {len(X_all)}")
# Out:
# Skupaj vzorcev: 2968

# %%
CRKA_ZA_IZVOZ = 'A'
SVG_POT = r'F:\FRI_DIPLOMSKA\-delovna mapa-\JUPY\ektorji_za_latex' + f'\\strokes_{CRKA_ZA_IZVOZ}.pdf'

indices = np.where(y_all == CRKA_ZA_IZVOZ)[0]
idx = np.random.choice(indices)

fig, ax = plt.subplots(figsize=(2, 2))
data = X_all[idx].reshape(MAX_STROKES, POINTS_PER_STROKE, 2)
for stroke in data:
    if stroke.sum() == 0:
        continue
    ax.plot(stroke[:, 0], 1 - stroke[:, 1], linewidth=2, color='black')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')
ax.set_aspect('equal')

plt.savefig(SVG_POT, format='pdf', bbox_inches='tight', pad_inches=0)
plt.close()

print(f"Shranjeno: {SVG_POT}")
# Out:
# Shranjeno: F:\FRI_DIPLOMSKA\-delovna mapa-\JUPY\ektorji_za_latex\strokes_A.pdf
