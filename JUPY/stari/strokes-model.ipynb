# %%
import tensorflow as tf
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# ============================================================
# 1. NASTAVITVE
# ============================================================
STROKE_DIR = r'C:\Users\cam\Documents\006_DIP\000_ourDATASET\dataset\strokes'
MAX_STROKES = 5
POINTS_PER_STROKE = 32
TEST_OSEBE = ['Ghhh', 'meu']  # osebe za testiranje
FILTER_CRKE = None  # None = vse črke, ali npr. ['A','B'] za samo A in B

# ============================================================
# 2. FUNKCIJE
# ============================================================
def resample_stroke(points, max_strokes=MAX_STROKES, points_per_stroke=POINTS_PER_STROKE):
    strokes = []
    current = []
    for p in points:
        if p['x'] == -1:
            if current:
                strokes.append(current)
                current = []
        else:
            current.append((p['x'], p['y']))
    if current:
        strokes.append(current)
    if not strokes:
        return None

    all_pts = np.array([p for s in strokes for p in s])
    x_min, x_max = all_pts[:,0].min(), all_pts[:,0].max()
    y_min, y_max = all_pts[:,1].min(), all_pts[:,1].max()

    result = np.zeros((max_strokes, points_per_stroke, 2))
    for i, stroke in enumerate(strokes[:max_strokes]):
        if len(stroke) < 2:
            continue
        coords = np.array(stroke)
        distances = np.sqrt(np.sum(np.diff(coords, axis=0)**2, axis=1))
        cumdist = np.concatenate([[0], np.cumsum(distances)])
        total_dist = cumdist[-1]
        if total_dist == 0:
            continue
        sample_points = np.linspace(0, total_dist, points_per_stroke)
        xs = np.interp(sample_points, cumdist, coords[:,0])
        ys = np.interp(sample_points, cumdist, coords[:,1])
        xs = (xs - x_min) / (x_max - x_min + 1e-8)
        ys = (ys - y_min) / (y_max - y_min + 1e-8)
        result[i] = np.column_stack([xs, ys])

    return result.flatten()  # 320 vrednosti

# ============================================================
# 3. NALOŽI PODATKE
# ============================================================
X_all, y_all, osebe_all = [], [], []

for filename in os.listdir(STROKE_DIR):
    if not filename.endswith('.json'):
        continue
    crka = filename[0]
    if FILTER_CRKE and crka not in FILTER_CRKE:
        continue

    parts = filename.split('_')
    oseba = parts[1] if len(parts) > 1 else 'unknown'

    with open(os.path.join(STROKE_DIR, filename), 'r') as f:
        points = json.load(f)

    resampled = resample_stroke(points)
    if resampled is None:
        continue

    X_all.append(resampled)
    y_all.append(crka)
    osebe_all.append(oseba)

X_all = np.array(X_all)
y_all = np.array(y_all)
osebe_all = np.array(osebe_all)

print(f"Skupaj vzorcev: {len(X_all)}")
print(f"Črke: {sorted(set(y_all))}")
print(f"Osebe: {sorted(set(osebe_all))}")

# ============================================================
# 4. TRAIN/TEST SPLIT PO OSEBAH
# ============================================================
train_mask = ~np.isin(osebe_all, TEST_OSEBE)
test_mask = np.isin(osebe_all, TEST_OSEBE)

X_train = X_all[train_mask]
y_train = y_all[train_mask]
X_test = X_all[test_mask]
y_test = y_all[test_mask]

print(f"\nTrain: {X_train.shape} — {np.unique(osebe_all[train_mask])}")
print(f"Test:  {X_test.shape} — {np.unique(osebe_all[test_mask])}")

le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)
print(f"Razredi: {le.classes_}")

# ============================================================
# 5. VIZUALIZACIJA VZORCEV
# ============================================================
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i in range(min(10, len(X_all))):
    data = X_all[i].reshape(5, 32, 2)
    for stroke in data:
        if stroke.sum() == 0:
            continue
        axes[i//5][i%5].plot(stroke[:,0], 1-stroke[:,1], linewidth=2)
    axes[i//5][i%5].set_title(f'{y_all[i]} ({osebe_all[i]})')
    axes[i//5][i%5].set_xlim(0, 1)
    axes[i//5][i%5].set_ylim(0, 1)
    axes[i//5][i%5].axis('off')
plt.suptitle('Stroke vzorci iz dataseta')
plt.tight_layout()
plt.show()

# ============================================================
# 6. MODEL
# ============================================================
n_classes = len(le.classes_)

stroke_model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(320,)),
    tf.keras.layers.Reshape((320, 1)),
    tf.keras.layers.Conv1D(32, 8, activation='relu'),
    tf.keras.layers.MaxPooling1D(2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv1D(64, 4, activation='relu'),
    tf.keras.layers.MaxPooling1D(2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

stroke_model.compile(optimizer='adam',
                     loss='sparse_categorical_crossentropy',
                     metrics=['accuracy'])

stroke_model.summary()

# ============================================================
# 7. TRENING
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True,
    verbose=1
)

history = stroke_model.fit(
    X_train, y_train_enc,
    epochs=100,
    batch_size=16,
    validation_data=(X_test, y_test_enc),
    callbacks=[early_stop],
    verbose=1
)

# ============================================================
# 8. REZULTATI
# ============================================================
_, train_acc = stroke_model.evaluate(X_train, y_train_enc, verbose=0)
_, test_acc = stroke_model.evaluate(X_test, y_test_enc, verbose=0)
print(f"\nTrain accuracy: {train_acc*100:.1f}%")
print(f"Test accuracy:  {test_acc*100:.1f}%")

# Graf
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# ============================================================
# 9. SHRANI
# ============================================================
os.makedirs(r'C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes', exist_ok=True)
stroke_model.save(r'C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes\stroke_model.keras')
stroke_model.export(r'C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes\stroke_model_saved')
print("Model shranjen!")
# Out:
# Skupaj vzorcev: 180
# Črke: [np.str_('A'), np.str_('B'), np.str_('C'), np.str_('Č')]
# Osebe: [np.str_('55'), np.str_('Ghhh'), np.str_('Ghhhhh'), np.str_('Hh'), np.str_('Ks'), np.str_('Pos'), np.str_('meu'), np.str_('test meu')]
#
# Train: (140, 320) — ['55' 'Ghhhhh' 'Hh' 'Ks' 'Pos' 'test meu']
# Test:  (40, 320) — ['Ghhh' 'meu']
# Razredi: ['A' 'B' 'C' 'Č']
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ reshape_2 (Reshape)                  │ (None, 320, 1)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_4 (Conv1D)                    │ (None, 313, 32)             │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_4 (MaxPooling1D)       │ (None, 156, 32)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 156, 32)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_5 (Conv1D)                    │ (None, 153, 64)             │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_5 (MaxPooling1D)       │ (None, 76, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 76, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 4864)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │         311,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 320,164 (1.22 MB)
#  Trainable params: 320,164 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.3000 - loss: 1.2890 - val_accuracy: 0.9750 - val_loss: 1.0914
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7286 - loss: 0.9158 - val_accuracy: 0.9750 - val_loss: 0.7018
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8429 - loss: 0.5187 - val_accuracy: 0.9750 - val_loss: 0.3453
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9571 - loss: 0.2233 - val_accuracy: 0.9750 - val_loss: 0.2314
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9786 - loss: 0.1121 - val_accuracy: 0.9750 - val_loss: 0.2253
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9929 - loss: 0.0598 - val_accuracy: 0.9750 - val_loss: 0.2463
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9929 - loss: 0.0337 - val_accuracy: 0.9750 - val_loss: 0.2570
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9786 - loss: 0.0567 - val_accuracy: 0.9750 - val_loss: 0.2506
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9786 - loss: 0.0571 - val_accuracy: 0.9750 - val_loss: 0.2493
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9929 - loss: 0.0336 - val_accuracy: 0.9750 - val_loss: 0.2579
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9929 - loss: 0.0255 - val_accuracy: 0.9750 - val_loss: 0.2670
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.9750 - val_loss: 0.2825
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9857 - loss: 0.0303 - val_accuracy: 0.9750 - val_loss: 0.2861
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9929 - loss: 0.0169 - val_accuracy: 0.9750 - val_loss: 0.2945
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9929 - loss: 0.0252 - val_accuracy: 0.9750 - val_loss: 0.2910
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
#
# Train accuracy: 100.0%
# Test accuracy:  97.5%
# INFO:tensorflow:Assets written to: C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes\stroke_model_saved\assets
# INFO:tensorflow:Assets written to: C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes\stroke_model_saved\assets
# Saved artifact at 'C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes\stroke_model_saved'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 320), dtype=tf.float32, name='keras_tensor_24')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2545900660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900661328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900662864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900659024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666320: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model shranjen!

# %%
# ============================================================
# 10. PRETVORBA V TFLITE (z optimizacijo za mikrokontrolerje)
# ============================================================
converter = tf.lite.TFLiteConverter.from_keras_model(stroke_model)

# Osnovna pretvorba
tflite_model = converter.convert()
with open(r'C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes\strokes.tflite', 'wb') as f:
    f.write(tflite_model)

# ŠE BOLJE: Kvantizacija (INT8 ali Float16) za hitrejši STM32
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
with open(r'C:\Users\cam\Documents\006_DIP\000_ourMODELS\strokes\74strokes\strokes_quant.tflite', 'wb') as f:
    f.write(tflite_quant_model)

print("TFLite modela (navaden in kvantiziran) shranjena!")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\cam\AppData\Local\Temp\tmpk3s2o64m\assets
# INFO:tensorflow:Assets written to: C:\Users\cam\AppData\Local\Temp\tmpk3s2o64m\assets
# Saved artifact at 'C:\Users\cam\AppData\Local\Temp\tmpk3s2o64m'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 320), dtype=tf.float32, name='keras_tensor_24')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2545900660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900661328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900662864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900659024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666320: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:tensorflow:Assets written to: C:\Users\cam\AppData\Local\Temp\tmp6mlilsdm\assets
# INFO:tensorflow:Assets written to: C:\Users\cam\AppData\Local\Temp\tmp6mlilsdm\assets
# Saved artifact at 'C:\Users\cam\AppData\Local\Temp\tmp6mlilsdm'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 320), dtype=tf.float32, name='keras_tensor_24')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2545900660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900661328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900662864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900659024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2545900666320: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite modela (navaden in kvantiziran) shranjena!

# %% [markdown]
# ** *********************************************** **

# %% [markdown]
# **Pretvorba v .bin file da ga bomo dali na vezje**

# %%
import numpy as np

# Seznam črk točno v takem vrstnem redu, kot ga imaš v SLO_ABECEDA v C kodi
labels_ordered = ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I',
                  'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š',
                  'T', 'U', 'V', 'Z', 'Ž']

# Ustvarimo mapiranje: 'A' -> 0, 'B' -> 1, ...
label_to_idx = {l: i for i, l in enumerate(labels_ordered)}

def export_benchmark_data(X, y, filename="test_samples.bin"):
    with open(filename, "wb") as f:
        for i in range(len(X)):
            # 1. Pretvori črko v številko (npr. 'Č' -> 3)
            char_label = str(y[i])
            if char_label not in label_to_idx:
                print(f"Opozorilo: Črka {char_label} ni v seznamu! Preskakujem.")
                continue
            
            numeric_label = label_to_idx[char_label]
            
            # 2. Pripravi točke (X_test so že floati med 0 in 1 ali podobno)
            # Uporabimo float32, ker AI model v C-ju to pričakuje
            points = X[i].astype(np.float32) 
            
            # 3. Zapakiraj (B=uint8, H=uint16, 320f=320 floatov)
            # Skupaj: 1 + 2 + (320 * 4) = 1283 bajtov na vzorec
            data = struct.pack(f'<BH320f', numeric_label, 160, *points)
            f.write(data)
            
    print(f"Končano! Ustvarjena datoteka '{filename}' s {len(X)} vzorci.")

# Zaženi
export_benchmark_data(X_test, y_test)
# Out:
# Končano! Ustvarjena datoteka 'test_samples.bin' s 40 vzorci.
