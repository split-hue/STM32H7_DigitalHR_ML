# %%
import tensorflow as tf
import numpy as np
import os
import struct
import matplotlib.pyplot as plt
from PIL import Image

# ============================================================
# 1. NASTAVITVE
# ============================================================
BITMAP_DIR = r'F:\FRI_DIPLOMSKA\-delovna mapa-\DATASET\dataset\bitmaps'
TEST_OSEBE = ['1009', 'pika', 'K']  # osebe za testiranje – enako kot pri strokes
FILTER_CRKE = None  # None = vse črke

# ============================================================
# 2. NALOŽI PODATKE
# ============================================================
X_all, y_all, osebe_all = [], [], []

for filename in os.listdir(BITMAP_DIR):
    if not filename.lower().endswith('.png'):
        continue

    parts = filename.split('_')
    crka = parts[0]          # npr. 'A_oseba123_529.png' -> 'A'
    oseba = parts[1] if len(parts) > 1 else 'unknown'

    if FILTER_CRKE and crka not in FILTER_CRKE:
        continue

    img = Image.open(os.path.join(BITMAP_DIR, filename)).convert('L')
    pixels = 1.0 - (np.array(img, dtype=np.float32) / 255.0)
    #pixels = np.array(img, dtype=np.float32) / 255.0  # [0, 1]

    X_all.append(pixels.flatten())  # 28x28 -> 784
    y_all.append(crka)
    osebe_all.append(oseba)

X_all = np.array(X_all)
y_all = np.array(y_all)
osebe_all = np.array(osebe_all)

print(f"Skupaj vzorcev: {len(X_all)}")
print(f"Črke: {sorted(set(y_all))}")
print(f"Osebe: {sorted(set(osebe_all))}")

# ============================================================
# 3. TRAIN/TEST SPLIT PO OSEBAH
# ============================================================
train_mask = ~np.isin(osebe_all, TEST_OSEBE)
test_mask  =  np.isin(osebe_all, TEST_OSEBE)

X_train = X_all[train_mask]
y_train = y_all[train_mask]
X_test  = X_all[test_mask]
y_test  = y_all[test_mask]

print(f"\nTrain: {X_train.shape} — {np.unique(osebe_all[train_mask])}")
print(f"Test:  {X_test.shape} — {np.unique(osebe_all[test_mask])}")



labels_ordered = ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I',
                  'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š',
                  'T', 'U', 'V', 'Z', 'Ž']
label_to_idx = {l: i for i, l in enumerate(labels_ordered)}
y_train_enc = np.array([label_to_idx[l] for l in y_train])
y_test_enc  = np.array([label_to_idx[l] for l in y_test])


# ============================================================
# 4. VIZUALIZACIJA VZORCEV
# ============================================================
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i in range(min(10, len(X_all))):
    axes[i//5][i%5].imshow(X_all[i].reshape(28, 28), cmap='gray')
    axes[i//5][i%5].set_title(f'{y_all[i]} ({osebe_all[i]})')
    axes[i//5][i%5].axis('off')
plt.suptitle('Bitmap vzorci iz dataseta')
plt.tight_layout()
plt.show()

# ============================================================
# 5. MODEL
# ============================================================
n_classes = len(labels_ordered)

bitmap_model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(784,)),
    tf.keras.layers.Reshape((28, 28, 1)),

    tf.keras.layers.SeparableConv2D(16, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.SeparableConv2D(32, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),

    #tf.keras.layers.Flatten(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

bitmap_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                     loss='sparse_categorical_crossentropy',
                     metrics=['accuracy'])
bitmap_model.summary()

# ============================================================
# 6. TRENING
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True,
    verbose=1
)

history = bitmap_model.fit(
    X_train, y_train_enc,
    epochs=100,
    batch_size=16,
    validation_data=(X_test, y_test_enc),
    callbacks=[early_stop],
    verbose=1
)

# ============================================================
# 7. REZULTATI
# ============================================================
_, train_acc = bitmap_model.evaluate(X_train, y_train_enc, verbose=0)
_, test_acc  = bitmap_model.evaluate(X_test,  y_test_enc,  verbose=0)
print(f"\nTrain accuracy: {train_acc*100:.1f}%")
print(f"Test accuracy:  {test_acc*100:.1f}%")

# Graf
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Skupaj vzorcev: 2968
# Črke: [np.str_('A'), np.str_('B'), np.str_('C'), np.str_('D'), np.str_('E'), np.str_('F'), np.str_('G'), np.str_('H'), np.str_('I'), np.str_('J'), np.str_('K'), np.str_('L'), np.str_('M'), np.str_('N'), np.str_('O'), np.str_('P'), np.str_('R'), np.str_('S'), np.str_('T'), np.str_('U'), np.str_('V'), np.str_('Z'), np.str_('Č'), np.str_('Š'), np.str_('Ž')]
# Osebe: [np.str_(',,'), np.str_('1009'), np.str_('232323'), np.str_('69'), np.str_('Ana'), np.str_('Bruih'), np.str_('CritKill'), np.str_('Diablo'), np.str_('Gabor'), np.str_('Gilda Fejniković'), np.str_('Hamorii'), np.str_('Hana'), np.str_('Hnabči'), np.str_('Janez'), np.str_('Janez Januš'), np.str_('Jerry'), np.str_('K'), np.str_('Klara'), np.str_('Ks'), np.str_('Ksenija'), np.str_('Lolek'), np.str_('Lt'), np.str_('Martin'), np.str_('NejcYami'), np.str_('Ok'), np.str_('Petra'), np.str_('Ponižni prevozniki'), np.str_('Pos1'), np.str_('Pos2'), np.str_('Poss'), np.str_('Steve'), np.str_('Tamara'), np.str_('Trupina'), np.str_('Turgcat'), np.str_('Vikipiki3'), np.str_('cilke'), np.str_('junci4'), np.str_('mr'), np.str_('nat'), np.str_('nina'), np.str_('pika'), np.str_('say gex'), np.str_('skadi'), np.str_('ub'), np.str_('Žiga'), np.str_('🐢')]
#
# Train: (2743, 784) — [',,' '232323' '69' 'Ana' 'Bruih' 'CritKill' 'Diablo' 'Gabor'
#  'Gilda Fejniković' 'Hamorii' 'Hana' 'Hnabči' 'Janez' 'Janez Januš'
#  'Jerry' 'Klara' 'Ks' 'Ksenija' 'Lolek' 'Lt' 'Martin' 'NejcYami' 'Ok'
#  'Petra' 'Ponižni prevozniki' 'Pos1' 'Pos2' 'Poss' 'Steve' 'Tamara'
#  'Trupina' 'Turgcat' 'Vikipiki3' 'cilke' 'junci4' 'mr' 'nat' 'nina'
#  'say gex' 'skadi' 'ub' 'Žiga' '🐢']
# Test:  (225, 784) — ['1009' 'K' 'pika']
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)                    │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d (SeparableConv2D)   │ (None, 28, 28, 16)          │              41 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_1 (SeparableConv2D) │ (None, 14, 14, 32)          │             688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 32)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 25)                  │             825 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,938 (23.20 KB)
#  Trainable params: 5,842 (22.82 KB)
#  Non-trainable params: 96 (384.00 B)
# Epoch 1/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.1028 - loss: 3.0848 - val_accuracy: 0.0400 - val_loss: 3.2126
# Epoch 2/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2253 - loss: 2.4577 - val_accuracy: 0.0400 - val_loss: 3.4577
# Epoch 3/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3361 - loss: 1.9723 - val_accuracy: 0.0400 - val_loss: 3.5156
# Epoch 4/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4408 - loss: 1.6571 - val_accuracy: 0.2044 - val_loss: 2.3122
# Epoch 5/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5129 - loss: 1.4769 - val_accuracy: 0.5244 - val_loss: 1.3700
# Epoch 6/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5578 - loss: 1.3214 - val_accuracy: 0.3200 - val_loss: 1.9704
# Epoch 7/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5716 - loss: 1.2714 - val_accuracy: 0.5022 - val_loss: 1.3957
# Epoch 8/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6238 - loss: 1.1539 - val_accuracy: 0.4267 - val_loss: 1.6767
# Epoch 9/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6442 - loss: 1.0843 - val_accuracy: 0.7244 - val_loss: 0.8721
# Epoch 10/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6562 - loss: 1.0386 - val_accuracy: 0.6133 - val_loss: 1.0570
# Epoch 11/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6759 - loss: 0.9759 - val_accuracy: 0.5111 - val_loss: 1.4971
# Epoch 12/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6934 - loss: 0.9311 - val_accuracy: 0.6489 - val_loss: 0.9763
# Epoch 13/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7197 - loss: 0.8657 - val_accuracy: 0.6756 - val_loss: 0.8476
# Epoch 14/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7120 - loss: 0.8648 - val_accuracy: 0.6311 - val_loss: 0.9847
# Epoch 15/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7382 - loss: 0.8051 - val_accuracy: 0.7911 - val_loss: 0.7033
# Epoch 16/100
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.

# ============================================================
converter = tf.lite.TFLiteConverter.from_keras_model(bitmap_model)

# Osnovna pretvorba
tflite_model = converter.convert()
with open(r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\bitmaps.tflite', 'wb') as f:
    f.write(tflite_model)

# ŠE BOLJE: Kvantizacija (INT8 ali Float16) za hitrejši STM32
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
with open(r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\bitmaps2.tflite', 'wb') as f:
    f.write(tflite_quant_model)

print("TFLite modela (navaden in kvantiziran) shranjena!")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpjid4m7vr\assets
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpjid4m7vr\assets
# Saved artifact at 'C:\Users\Ksenija\AppData\Local\Temp\tmpjid4m7vr'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 784), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 25), dtype=tf.float32, name=None)
# Captures:
#   2373426166480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426166288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426165328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426166864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426167632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426167440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426166672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444160016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444160208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444157904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444159632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444159440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444159824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444162320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444160784: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpt8e65yno\assets
# INFO:tensorflow:Assets written to: C:\Users\Ksenija\AppData\Local\Temp\tmpt8e65yno\assets
# Saved artifact at 'C:\Users\Ksenija\AppData\Local\Temp\tmpt8e65yno'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 784), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 25), dtype=tf.float32, name=None)
# Captures:
#   2373426166480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426166288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426165328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426166864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426167632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426167440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373426166672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444160016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444160208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444157904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444158672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444159632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444159440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444159824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444162320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2373444160784: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite modela (navaden in kvantiziran) shranjena!

# %% [markdown]
# **Pretvorba v .bin file da ga bomo dali na vezje**

# %%
# import numpy as np

# # Seznam črk točno v takem vrstnem redu, kot ga imaš v SLO_ABECEDA v C kodi
# labels_ordered = ['A', 'B', 'C', 'Č', 'D', 'E', 'F', 'G', 'H', 'I',
#                   'J', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'Š',
#                   'T', 'U', 'V', 'Z', 'Ž']

# # Ustvarimo mapiranje: 'A' -> 0, 'B' -> 1, ...
# label_to_idx = {l: i for i, l in enumerate(labels_ordered)}

# def export_benchmark_data(X, y, filename=r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\zbirka_bitmaps.bin'):
#     with open(filename, "wb") as f:
#         for i in range(len(X)):
#             # 1. Pretvori črko v številko (npr. 'Č' -> 3)
#             char_label = str(y[i])
#             if char_label not in label_to_idx:
#                 print(f"Opozorilo: Črka {char_label} ni v seznamu! Preskakujem.")
#                 continue

#             numeric_label = label_to_idx[char_label]

#             # 2. Pripravi piksle (X_test so že floati med 0 in 1)
#             # Uporabimo float32, ker AI model v C-ju to pričakuje
#             pixels = X[i].astype(np.float32)

#             # 3. Zapakiraj (B=uint8, H=uint16, 784f=784 floatov)
#             # Skupaj: 1 + 2 + (784 * 4) = 3139 bajtov na vzorec
#             data = struct.pack('<BH784f', numeric_label, 784, *pixels)
#             f.write(data)

#     print(f"Končano! Ustvarjena datoteka '{filename}' s {len(X)} vzorci.")

# # Zaženi
# export_benchmark_data(X_test, y_test)

# %%
a_indices = np.where(y_all == 'A')[0]
a_idx = np.random.choice(a_indices)
plt.imshow(X_all[a_idx].reshape(28, 28), cmap='gray')
plt.title(f"Slika (app): A")
plt.axis('off')
plt.show()

# %%
a_indices = np.where(y_all == 'A')[0]
a_idx = np.random.choice(a_indices)
plt.imshow(X_all[a_idx].reshape(28, 28), cmap='gray_r')
plt.title(f"Slika (obrazec): A")
plt.axis('off')
plt.show()

# %%
print(f"Skupaj vzorcev: {len(X_all)}")
# Out:
# Skupaj vzorcev: 2968

# %%
import os

path1 = r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\bitmaps.tflite'
path2 = r'F:\FRI_DIPLOMSKA\-delovna mapa-\MODEL\bitmaps\bitmaps2.tflite'

size1 = os.path.getsize(path1) / 1024  # KB
size2 = os.path.getsize(path2) / 1024  # KB

print(f"Navaden model: {size1:.2f} KB")
print(f"Kvantiziran model: {size2:.2f} KB")
# Out:
# Navaden model: 30.32 KB
# Kvantiziran model: 19.52 KB

# %%
CRKA_ZA_IZVOZ = 'A'
SVG_POT = r'F:\FRI_DIPLOMSKA\-delovna mapa-\JUPY\ektorji_za_latex' + f'\\bitmaps_{CRKA_ZA_IZVOZ}.pdf'

indices = np.where(y_all == CRKA_ZA_IZVOZ)[0]
idx = np.random.choice(indices)

fig, ax = plt.subplots(figsize=(2, 2))
ax.imshow(X_all[idx].reshape(28, 28), cmap='gray_r', interpolation='nearest')
ax.axis('off')

plt.savefig(SVG_POT, format='pdf', bbox_inches='tight', pad_inches=0)
plt.close()

print(f"Shranjeno: {SVG_POT}")
# Out:
# Shranjeno: F:\FRI_DIPLOMSKA\-delovna mapa-\JUPY\ektorji_za_latex\bitmaps_A.pdf
